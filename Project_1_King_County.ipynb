# %% [markdown]
# <a href="https://colab.research.google.com/github/ninowwwup/Project_1_King_County/blob/main/Project_1_King_County.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mini Projeto King County
#
# Analista: Francisco de Lima Silva
#
# Corretora: Roof Imoveis
#
# RID #57320

# %% [markdown]
# # **🔶Business Understanding (Entendimento de Negócio)**

# %% [markdown]
# ---

# %% [markdown]
# 1. **Avaliando a Situação / Background do Projeto**

# %% [markdown]
# > Segundo o site Wikipedia, o condado de King County, Washington, é um dos mais populosos dos 39 condados dos EUA, tendo como sede Seatle, com maior densidade populacional de todo o condado, por sua vez, também concentra o maior preço de imóveis e maior fluxo de venda e compra.
#
#
#
# > Roof Imóveis é uma das maiores empresas do ramo imobiliário brasileiro e quer expandir sua área de atuação fazendo um investimento internacional. A empresa irá investir em imóveis no Condado de County, nos Estados Unidos, com isso ela solicita uma consultoria de negócio afim de obter informações preditivas sobre possíveis investimentos nessa região dos EUA.

# %% [markdown]
# ---

# %% [markdown]
# 2. **Objetivo de Negócio**

# %% [markdown]
# > A **Roof Imóveis** quer saber qual seria os *5 imóveis que ela deveria investir e o porquê e quais 5 imóveis não deve investir de jeito nenhum.*

# %% [markdown]
# ---

# %% [markdown]
# 3. **Objetivos e metas para a Mineração dos Dados (Determine Data Mining Goals)**

# %% [markdown]
# ✅   *Analisar o que mais tende a influenciar no preço dos imóveis;*
#
# ✅   *Encontrar a cidade de cada imóvel;*
#
# ✅   *Calcular o preço por área de imóveis;*
#
# ✅   *Calcular o lucro/ perda de investimentos caso o imóvel seja vendido mais de uma vez naquele período.*

# %% [markdown]
# ---

# %% [markdown]
# 4. **Critério de Sucesso**

# %% [markdown]
# > Mostrar de forma preditiva através da limpeza e modelagem dos dados uma analíse detalhada e cuidadosa sobre investimentos seguros dos clientes.

# %% [markdown]
# ---

# %% [markdown]
# # **🔶Data Understanding (Entendimento dos Dados)**

# %% [markdown]
# 1. **Coleta Inicial dos Dados (Collect Initial Data)**

# %% [markdown]
# Os dataset utilizado para análise foi coletado no site: https://www.kaggle.com/harlfoxem/housesalesprediction

# %% [markdown]
# ---

# %% [markdown]
# 2. **Descrição dos Dados (Describe data)**

# %% [markdown]
# - Os dados coletados são do tipo (**.csv**).
#
# - O Dataset apresenta a venda de imóveis e suas características na região
# de Maio de 2014 à Maio de 2015.
#
# - Tem um total de *21613 registros com um total
# de 21 atributos*

# %% [markdown]
# ---

# %% [markdown]
# 3. **Exploração dos Dados (Explore Data)**

# %% [markdown]
# - Visualização dos Dados
# - Estatística Simples
# - Relatório da Exploração dos Dados (Data Exploration Report)

# %%
# Importando as Bibliotecas de manipulação e tratamento dos dados

import pandas as pd
import numpy as np

# Libs de plotagem e visualização dos dados

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.figure_factory as ff

# Estilizando os gráficos plotados 

plt.style.use('ggplot')

# %%
# Define a largura máxima das colunas

pd.set_option('display.max_column', None)

# Importando e vizualizando o dataset

df = pd.read_csv('/content/kc_house_data.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 0             1180      5650     1.0           0     0          3      7
# ...

# %%
# Número de Registros do Dataset

df.shape
# Out:
# (21613, 21)

# %%
# Visualizando o tipo dos dados em cada coluna

df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
# Observando se há dados nulos

df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
# Descrição estatística dos dados

df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# 3.1 Observamos que existem dados atípicos na contagem de números de quartos mostrando casas com uma máxima de 33 quartos.
#
# 3.2 Também observamos que há números com casa decimal (float) na coluna *'bathrooms'*.
#
# Fazendo uma breve pesquisa sobre o caso, o site **Idea Glass**:
#
# link: https://www.ideiaglass.com.br/dicas/qual-e-a-diferenca-entre-banheiro-lavabo-e-sala-de-banho/#:~:text=Veja%20abaixo%3A-,Lavabo,bacia%20sanit%C3%A1ria%20j%C3%A1%20s%C3%A3o%20suficientes%20para%20que%20um%20lavabo%20seja%20completo.,-Banheiro
#
# Mostra que se os dados que apresentam numeros decimais (float) se trata de um **lavabo**, ambientes para visitas eventualmente integrado à área social ou sala de estar, contendo menos elementos que um banheiro tradicional, ou uma sala de banho com jacuzzi. típico de imóveis mais refinados e comum nos EUA.

# %%
# Verificando que a coluna 'date' está com formato tipo object
# Tratando esse dado

df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
df.head(3)
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# 1            400      1951          1991    98125  47.7210 -122.319
# 2              0      1933             0    98028  47.7379 -122.233
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062

# %%
# Correlação das colunas

df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
# plotando um gráfico de calor para visualizar como estão correlacionadas as colunas do dataset

fig, ax = plt.subplots(figsize=(23, 8))
plt.title("Correlação das colunas entre si")

sns.heatmap(df.corr(), cmap = 'RdBu_r', linewidth = 0.5, annot = True);

# %%
# Correlação da coluna 'price' com as demais colunas

df.corr()['price'].sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# lat              0.307003
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# condition        0.036362
# long             0.021626
# id              -0.016762
# zipcode         -0.053203
# Name: price, dtype: float64

# %% [markdown]
# - Vemos acima que algumas colunas se correalcionam com o a coluna *'price'*
# - Sendo elas:
#
#  1. 'sqft_living15'
#  2. 'sqft_above'
#  3. 'sqft_living'
#  4. 'bathrooms'
#  5. 'grade'

# %%
# Plotando apenas as que mais se corralacionam

cols = df[['price','sqft_living', 'grade', 'sqft_above', 'sqft_living15', 'bathrooms']]
most_corr_var = cols.corr()

plt.figure(figsize=[10, 10])
plt.title('')
sns.heatmap(data=most_corr_var, vmin=-1, vmax=1, linewidth=0.01, linecolor='black', cmap='RdBu_r', annot=True)

plt.show()

# %% [markdown]
# ✅ *Analisar o que mais tende a influenciar no preço dos imóveis*

# %% [markdown]
# - Ao observar melhor a correlação ampliada das colunas que mais influenciam o preços dos imóveis *('price)*, vemos que o tamanho da área habitável em ft² *('sqft_living')*, é a que mais influencia no preço.

# %% [markdown]
# ---

# %%
# Instalando a lib para descompactar as cidades em 'zipcode'

# !pip install uszipcode
from uszipcode import SearchEngine
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 121 kB 13.3 MB/s
# ...
#      |████████████████████████████████| 76 kB 5.5 MB/s
# ...
# /usr/local/lib/python3.8/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
#Criando uma nova coluna vazia para cidade
df['City'] = np.nan

cidades = SearchEngine()
for index, row in df.iterrows():
  zipcode = cidades.by_zipcode(df['zipcode'][index])
  df['City'][index] = zipcode.major_city
# Out:
# Download /root/.uszipcode/simple_db.sqlite from https://github.com/MacHu-GWU/uszipcode-project/releases/download/1.0.1.db/simple_db.sqlite ...
#   1.00 MB downloaded ...
#   2.00 MB downloaded ...
#   3.00 MB downloaded ...
#   4.00 MB downloaded ...
#   5.00 MB downloaded ...
#   6.00 MB downloaded ...
#   7.00 MB downloaded ...
#   8.00 MB downloaded ...
#   9.00 MB downloaded ...
#   10.00 MB downloaded ...
#   11.00 MB downloaded ...
#   Complete!

# %%
# Conferindo a nova coluna com as cidades

df.head(20)
# Out:
#             id       date      price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520 2014-10-13   221900.0         3       1.00         1180
# 1   6414100192 2014-12-09   538000.0         3       2.25         2570
# 2   5631500400 2015-02-25   180000.0         2       1.00          770
# 3   2487200875 2014-12-09   604000.0         4       3.00         1960
# 4   1954400510 2015-02-18   510000.0         3       2.00         1680
# 5   7237550310 2014-05-12  1225000.0         4       4.50         5420
# 6   1321400060 2014-06-27   257500.0         3       2.25         1715
# 7   2008000270 2015-01-15   291850.0         3       1.50         1060
# 8   2414600126 2015-04-15   229500.0         3       1.00         1780
# 9   3793500160 2015-03-12   323000.0         3       2.50         1890
# 10  1736800520 2015-04-03   662500.0         3       2.50         3560
# 11  9212900260 2014-05-27   468000.0         2       1.00         1160
# ...

# %% [markdown]
# ✅   *Encontrar a cidade de cada imóvel*

# %% [markdown]
# - Ao analizar a nova coluna percebemos que alguns imóveis foram vendidos mais de uma vez

# %% [markdown]
# ---

# %%
# Criado uma nova coluna, calculando o preço pela área dos imóveis
# Chamando a nova coluna de Price_area

for index, row in df.iterrows():
  df['Price_area'] = df['price'] / df['sqft_living']

# %%
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# ...

# %% [markdown]
# ✅ Calcular o preço por área de imóveis

# %% [markdown]
# ---

# %%
# Gráfico mostrando o preço por área dos imóveis em cada cidade

fig = plt.figure(figsize=(20, 6))
plt.title('Valor dos Imóveis de acordo com a área em que estão localizados', loc = 'center', fontsize = 18, fontweight = 'bold')
plt.ylabel('Preço', fontsize = 18, fontweight = 'bold')
plt.grid(b=True, color='black', alpha= 0.5)
plt.rcParams['font.size'] = 12

# Gráfico do tipo barras 

plt.bar(df["City"], df["Price_area"], color='black')
plt.xticks(rotation=40);

# %% [markdown]
# - Vemos no gráfico que a grande maioria das vendas de imóveis está localizada em Seattle, Renton, Bellevue, Kent, Redmond, Kirland e Auburn
#
# - Como Seatle é a capital os dados concentram o maior fluxo de vendas nessa cidade em particular

# %%
df.dtypes
# Out:
# id                        int64
# date             datetime64[ns]
# price                   float64
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# City                     object
# Price_area              float64
# dtype: object

# %%
#Calculando ganho/perda de investimento em imóveis que foram vendidos mais de uma vez
#Verificando duplicados

resale = df[df.duplicated(['id'], keep=False)].sort_values(by='id')
resale
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 2497      1000102 2015-04-22  300000.0         6       3.00         2400
# 2496      1000102 2014-09-16  280000.0         6       3.00         2400
# 16814     7200179 2014-10-16  150000.0         2       1.00          840
# 16815     7200179 2015-04-24  175000.0         2       1.00          840
# 11434   109200390 2014-10-20  250000.0         3       1.75         1480
# ...           ...        ...       ...       ...        ...          ...
# 6345   9828200460 2014-06-27  260000.0         2       1.00          700
# 15200  9834200305 2015-02-10  615000.0         3       1.00         1790
# 15199  9834200305 2014-07-16  350000.0         3       1.00         1790
# 1085   9834200885 2014-07-17  360000.0         4       2.50         2080
# 1086   9834200885 2015-04-20  550000.0         4       2.50         2080
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# ...

# %%
# Conferindo o preço de imóveis agrupados pela frequência de vendas 

frequency = df.groupby('id').price.diff().dropna().plot.hist()

# %% [markdown]
# - Há imóveis que foram vendidos 2 vezes e outros 3 vezes. Interesante observar que o preço tem aumentado com relação a frequência de revenda desses imóveis

# %% [markdown]
# - Ao fazer uma breve pesquisa sobre o assunto, observamos que alguns fatores podem influenciar nos preços de revendas de imóveis como a questão de um novo telhado. A maioria dos compradores não consegue lidar com grandes despesas, como a instalação de um novo telhado, depois de terem acabado de comprar uma casa. Para errar por excesso de cautela, eles simplesmente não podem fazer uma oferta para uma casa com um telhado mais antigo, destaca o site **Iko** sobre um relatório de impacto de remodelação feito pela **NARI (National Association of the Remodeling Industry)**: https://www.iko.com/na/blog/does-a-new-roof-increase-home-value/#:~:text=No%20entanto%2C%20outra,seu%20novo%20telhado.

# %%
# Calculando o lucro máximo dos imóveis

list = []

df_profit = df.sort_values(['id', 'date']).reset_index(drop=True)

for i in range(0, df_profit.shape[0]):
  if i == 0:
    list.append(0)

# %%
df_profit.head(10)
# Out:
#         id       date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  1000102 2014-09-16  280000.0         6       3.00         2400      9373
# 1  1000102 2015-04-22  300000.0         6       3.00         2400      9373
# 2  1200019 2014-05-08  647500.0         4       1.75         2060     26036
# 3  1200021 2014-08-11  400000.0         3       1.00         1460     43000
# 4  2800031 2015-04-01  235000.0         3       1.00         1430      7599
# 5  3600057 2015-03-19  402500.0         4       2.00         1650      3504
# 6  3600072 2015-03-30  680000.0         4       2.75         2220      5310
# 7  3800008 2015-02-24  178000.0         5       1.50         1990     18200
# 8  5200087 2014-07-09  487000.0         4       2.50         2540      5001
# 9  6200017 2014-11-12  281000.0         3       1.00         1340     21336
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
# Agrupando os dados duplicados pelo ID

df_profit.groupby('id').count()
# Out:
#             date  price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id
# 1000102        2      2         2          2            2         2       2
# 1200019        1      1         1          1            1         1       1
# 1200021        1      1         1          1            1         1       1
# 2800031        1      1         1          1            1         1       1
# 3600057        1      1         1          1            1         1       1
# ...          ...    ...       ...        ...          ...       ...     ...
# 9842300095     1      1         1          1            1         1       1
# 9842300485     1      1         1          1            1         1       1
# 9842300540     1      1         1          1            1         1       1
# 9895000040     1      1         1          1            1         1       1
# 9900000190     1      1         1          1            1         1       1
#
# ...

# %%
# Conferindo valores MENORES preço em ft²

df_min_price = df_profit.sort_values(by=['Price_area'])
df_min_price.head()
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 7715   2891000610 2014-12-11  148900.0         4       1.75         1700
# 1515    723049156 2014-05-23  149000.0         3       1.00         1700
# 13653  5637200450 2014-10-17  257000.0         5       2.75         2930
# 12678  5111400086 2014-05-12  110000.0         3       1.00         1250
# 9023   3342700465 2015-01-23  250000.0         3       1.50         2840
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 7715       6000     1.0           0     0          3      7        1700
# 1515       8645     1.0           0     0          3      6        1700
# 13653     10148     2.0           0     0          3      9        2930
# 12678     53143     1.0           0     0          5      6        1250
# 9023      10182     1.0           0     0          3      8        1510
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df_min_price.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
# Conferindo valores MAIORES preço em ft²

df_max_price = df_profit.sort_values(by=['Price_area'], ascending=False)
df_max_price.head()
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 13855  6021500970 2015-04-07   874950.0         2       1.00         1080
# 1541    724069059 2014-05-09  2400000.0         3       2.25         3000
# 2379   1118000320 2015-05-08  3400000.0         4       4.00         4260
# 14382  6303400395 2015-01-30   325000.0         1       0.75          410
# 12198  4389200610 2014-12-01   903000.0         2       1.50         1140
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 13855      4000     1.0           0     0          3      7        1080
# 1541      11665     1.5           1     4          3     11        3000
# 2379      11765     2.0           0     0          3     11        3280
# 14382      8636     1.0           0     0          2      4         410
# 12198      7800     1.0           0     0          4      6        1140
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %% [markdown]
# ✅ Calcular o lucro/ perda de investimentos caso o imóvel seja vendido mais de uma vez naquele período

# %%
# Plotando um gráfico do tipo histograma para verificar melhor as colunas 'bathrooms' e 'bedrooms'

df_profit[['bathrooms', 'bedrooms']].hist(bins=80, alpha=1.0, color='red', figsize=(10,7));

# %% [markdown]
# -  O valor das residências tende a aumentar de acordo com o número de quartos, de 1 a 5 quartos
#
# - Observando o gráfico *'bathrooom'*, o número de banheiros, mostra entre 3 e 4 os banheiros com maior concentração de vendas.

# %% [markdown]
# # 🔶 Target Report (Relatório Alvo)

# %% [markdown]
# - Por fim, vamos ao relatório alvo sobre as análises feitas desse dataset.

# %% [markdown]
# ✅ Vemos acima que a venda e revenda de imóveis está concentradas em grandes centros, como Seatle, Renton e Bellevue;
#
#
# ✅ Também vimos que os dados que apresentam numeros float (decimal) tratam-se de
# lavabos, e os imóveis que contém essas característica possuem preços mais elevados, penssando em luxo, conforto e comodidade. São uma bela opção para gostos mais refindos;
#
#
# ✅ Os dados mstram que a correlação do preço dos imóveis pela área habitável em ft² tem maior influência nos preços. isso indica que os imóveis com maior extenção de área tendem a ser mais caros;
#
#
# ✅ Ao analisarmos os dados das vendas duplicadas, observei que mesmo os imóvel tenham sido vendidos mais de 1 vez, seu preço teve aumento. E ao pesquisar sobre, pude notar que muitos proprietários tendem a fazer reformas para a venda de imóveis temendo a desvalorização do mesmo por não estarem em condições de mercado de corretagem.
#
#
# ✅ O número de quartos também influencia no preços dos imóveis sendo 1-4 quartos os valores com mais densidade. o mesmo ocorre ao número de banheiros, mostrando que 3 e 4 banehiros são requisitados às corretoras
